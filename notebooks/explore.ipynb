# %%
# %load_ext kedro.ipython
# %load_ext autoreload
# %autoreload 2
# Out:
# [10/18/22 22:17:44] INFO     Updated path to Kedro project:                                          ]8;id=102632;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=922711;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\ipython\__init__.py#54\54]8;;\
#                              C:\Users\Baptiste\Github\kedro-spaceflights
# [10/18/22 22:17:45] INFO     Kedro project Kedro Spaceflights                                        ]8;id=324358;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\ipython\__init__.py\__init__.py]8;;\:]8;id=291962;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\ipython\__init__.py#77\77]8;;\
# ...

# %%
companies = catalog.load("companies")
reviews = catalog.load("reviews")
shuttles = catalog.load("shuttles")
# Out:
#                     INFO     Loading data from 'companies' (CSVDataSet)...                      ]8;id=887662;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=300811;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
#                     INFO     Loading data from 'reviews' (CSVDataSet)...                        ]8;id=526897;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\io\data_catalog.py\data_catalog.py]8;;\:]8;id=223883;file://c:\Users\Baptiste\Github\kedro-spaceflights\env\kedro-spaceflights\lib\site-packages\kedro\io\data_catalog.py#343\343]8;;\
# ...

# %%
companies
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>company_rating</th>
#       <th>company_location</th>
#       <th>total_fleet_count</th>
#       <th>iata_approved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35029</td>
#       <td>100%</td>
#       <td>Niue</td>
#       <td>4.0</td>
#       <td>f</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>30292</td>
#       <td>67%</td>
#       <td>Anguilla</td>
#       <td>6.0</td>
#       <td>f</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19032</td>
#       <td>67%</td>
#       <td>Russian Federation</td>
#       <td>4.0</td>
# ...

# %%
reviews
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>shuttle_id</th>
#       <th>review_scores_rating</th>
#       <th>review_scores_comfort</th>
#       <th>review_scores_amenities</th>
#       <th>review_scores_trip</th>
#       <th>review_scores_crew</th>
#       <th>review_scores_location</th>
#       <th>review_scores_price</th>
#       <th>number_of_reviews</th>
#       <th>reviews_per_month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63561</td>
#       <td>97.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>10.0</td>
#       <td>9.0</td>
#       <td>10.0</td>
#       <td>133</td>
# ...

# %%
shuttles
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>shuttle_location</th>
#       <th>shuttle_type</th>
#       <th>engine_type</th>
#       <th>engine_vendor</th>
#       <th>engines</th>
#       <th>passenger_capacity</th>
#       <th>cancellation_policy</th>
#       <th>crew</th>
#       <th>d_check_complete</th>
#       <th>moon_clearance_complete</th>
#       <th>price</th>
#       <th>company_id</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>63561</td>
#       <td>Niue</td>
#       <td>Type V5</td>
#       <td>Quantum</td>
#       <td>ThetaBase Services</td>
#       <td>1.0</td>
#       <td>2</td>
# ...

# %%
from kedro_spaceflights.pipelines.data_processing.nodes import preprocess_companies, preprocess_shuttles, create_model_input_table

# %%
preprocess_companies(companies)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id</th>
#       <th>company_rating</th>
#       <th>company_location</th>
#       <th>total_fleet_count</th>
#       <th>iata_approved</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35029</td>
#       <td>1.00</td>
#       <td>Niue</td>
#       <td>4.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>30292</td>
#       <td>0.67</td>
#       <td>Anguilla</td>
#       <td>6.0</td>
#       <td>False</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>19032</td>
#       <td>0.67</td>
#       <td>Russian Federation</td>
#       <td>4.0</td>
# ...

# %%
preprocess_shuttles(shuttles)
# Out:
# [10/18/22 22:17:52] WARNING  C:\Users\Baptiste\Github\kedro-spaceflights\src\kedro_spaceflights\pip ]8;id=673710;file://C:\Users\Baptiste\.pyenv\pyenv-win\versions\3.10.7\lib\warnings.py\warnings.py]8;;\:]8;id=755880;file://C:\Users\Baptiste\.pyenv\pyenv-win\versions\3.10.7\lib\warnings.py#109\109]8;;\
#                              elines\data_processing\nodes.py:20: FutureWarning: The default value
#                              of regex will change from True to False in a future version. In
#                              addition, single character regular expressions will *not* be treated
#                              as literal strings when regex=True.
#                                x = x.str.replace("$", "").str.replace(",", "")
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# ...

# %%
create_model_input_table(shuttles, companies, reviews)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>id_x</th>
#       <th>shuttle_location</th>
#       <th>shuttle_type</th>
#       <th>engine_type</th>
#       <th>engine_vendor</th>
#       <th>engines</th>
#       <th>passenger_capacity</th>
#       <th>cancellation_policy</th>
#       <th>crew</th>
#       <th>d_check_complete</th>
#       <th>...</th>
#       <th>review_scores_crew</th>
#       <th>review_scores_location</th>
#       <th>review_scores_price</th>
#       <th>number_of_reviews</th>
#       <th>reviews_per_month</th>
#       <th>id_y</th>
#       <th>company_rating</th>
#       <th>company_location</th>
#       <th>total_fleet_count</th>
# ...
